# %%
import numpy as p
import matplotlib.pyplot as plt

# Persamaan garis pertama melewati titik (a,b) dan (c,d)
a=2 #Titik (a,b)
b=2
c=4 #Titik (c,d)
d=6
m1=(d-b)/(c-a)
print("Gradien garis pertama adalah {}".format(m1))
print("Persamaan garis pertama adalah y={}x+{} ".format(m1,-m1*a+b))
#y1 = m1*(x-a)+b
# Out:
# Gradien garis pertama adalah 2.0
# Persamaan garis pertama adalah y=2.0x+-2.0

# %%
# Persamaan garis pertama kedua melewati titik (e,f) dan (g,h)
e=1 #Titik (e,f)
f=1
g=2 #Titik(g,h)
h=-3
m2=(h-f)/(g-e)
print("Gradien garis kedua adalah {}".format(m2))
print("Persamaan garis kedua adalah y={}x+{}".format(m2,-m2*e+f))
#y2=m2*(x-e)+f
# Out:
# Gradien garis kedua adalah -4.0
# Persamaan garis kedua adalah y=-4.0x+5.0

# %%
if m1==m2:
   print("Gradien sama, jadi kemungkinannya ga ada solusi atau solusinya banyak.")
else:
    # Titik potong kedua garis pada (tp_x,tp_y)
    tp_x = (m1*a-b-m2*e+f)/(m1-m2)
    tp_y = m2*(tp_x-e)+f
    
    print("Titik potong untuk adalah ({},{})".format (tp_x,tp_y))
# Out:
# Titik potong untuk adalah (1.1666666666666667,0.33333333333333304)

# %%
x = np.numpy(tp_x-5,tp_x+5,0.01)
plt.figure(figsize=(4,4),dpi=500)
​
plt.plot(x,m1*(x-a)+b,color='red',label='y={}x+{}'.format(m1,-m1*a+b))
plt.plot(x,m2*(x-e)+f,color='blue',label='y={}x+{}'.format(m2,-m2*e+f))
plt.plot(tp_x,tp_y,color='green',marker='x',markersize=4)
plt.legend(loc='best')
plt.show()
